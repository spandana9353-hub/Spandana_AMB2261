# %%
Spandana N R AMB2261

# %%
# List of crops
crops = ["Rice", "Wheat", "Maize"]
# Display crops
print("Crops grown in the field:")
for i in crops:
    print(i)
# Out:
# Crops grown in the field:
# Rice
# Wheat
# Maize

# %%
crops.append("Sugarcane") #adding new crop
print(crops)
#display the number of crops
print("Number of crops grown:", len(crops))
# Out:
# ['Rice', 'Wheat', 'Maize', 'Sugarcane']
# Number of crops grown: 4

# %%
if "Maize" in crops:
    print("Maize is present in the list of crops")
if "onion" in crops:
    print("onion is present in the list of crops")
else:
    print("onion is not present in the list of crops")
# Out:
# Maize is present in the list of crops
# onion is not present in the list of crops

# %%
crops.remove("Wheat")
print(crops)
print(len(crops))
# Out:
# ['Rice', 'Maize', 'Sugarcane']
# 3

# %%
# Find index of a crop
index_maize = crops.index("Maize")
print("Maize is at index:", index_maize)
print(crops.index("Maize"))
# Out:
# Maize is at index: 1
# 1

# %%
# Insert a new crop at a specific position
crops.insert(1, "Sugarcane")
print("After inserting Sugarcane:")
print(crops)
# Out:
# After inserting Sugarcane:
# ['Rice', 'Sugarcane', 'Maize', 'Sugarcane']

# %%
# Count how many times Sugarcane is grown
Sugarcane_count = crops.count("Sugarcane")
print("Sugarcane is grown", Sugarcane_count, "times")
# Out:
# Sugarcane is grown 2 times

# %%
# Remove last crop
crops.pop()
print("\nAfter removing last crop:")
print(crops)
# Out:
# After removing last crop:
# ['Rice', 'Sugarcane', 'Maize']

# %%
# Sort the crops
crops.sort()
print("Crops after sorting:")
print(crops)

# Reverse the list
crops.reverse()
print("Crops after reversing:")
print(crops)
# Out:
# Crops after sorting:
# ['Maize', 'Rice', 'Sugarcane']
# Crops after reversing:
# ['Sugarcane', 'Rice', 'Maize']
