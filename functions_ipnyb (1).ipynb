# %% [markdown]
# Spandana N R AMB2261

# %%
def fun(x):
  print("local x is:",x)
  x=4
  print("changed local x to:",x)
x=50
fun(x)
print("x is still:",x)
# Out:
# local x is: 50
# changed local x to: 4
# x is still: 50

# %%
def fun1():
  y=2
  print("changed y is",y)
y=50
fun1()
print("value of y:",y)
# Out:
# changed y is 2
# value of y: 50

# %%
def fun1():
  global y
  print("y is:",y)
  y=2
  print("changed y is",y)
y=50
fun1()
print("value of y:",y)
# Out:
# y is: 50
# changed y is 2
# value of y: 2

# %%
def printme(str):
  print(str)
  #return

#printme() type error
printme("hello")
printme(1234)
# Out:
# hello
# 1234

# %%
def printme(str):
  print(str)
  #return

#printme() type error
#printme("hello","bye")  error it takes 1 argument
printme("hello")
printme(1234)
# Out:
# hello
# 1234

# %%
def printme(str):
  print(str)
  #return

printme("hello") # required argument
printme(str="our world")
#printme(abc="our world") error abc is unkown argument
# Out:
# hello
# our world

# %%
def fun(a,b=5,c=10):
  print("a is",a,"and b is",b,"and c is",c)
fun(3,8)
fun(4,c=6)
fun(c=4,a=6)
fun(a=3,c=5)
# Out:
# a is 3 and b is 8 and c is 10
# a is 4 and b is 5 and c is 6
# a is 6 and b is 5 and c is 4
# a is 3 and b is 5 and c is 5

# %%
def fun(a,b,c):
 print("a is",a,"and b is",b,"and c is",c)
fun(3,8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1724821250.py in <cell line: 0>()
#       1 def fun(a,b,c):
#       2  print("a is",a,"and b is",b,"and c is",c)
# ----> 3 fun(3,8)
#
# TypeError: fun() missing 1 required positional argument: 'c'

# %%
def check(name,*marks):
  print(name)
  print(marks)
check("sonu",10,20,30)
# Out:
# sonu
# (10, 20, 30)

# %%
file=open("gkvk.text",'r')
content=file.read()
print(content)
file.close()
# Out:
# good morning
# how are you guys..
# how are you guys..

# %%
file=open("gkvk.text","w")
file.write("good morning")
file.close()

# %%
file=open("gkvk.text","a")
file.write("\nhow are you guys..")
file.close()

# %%
file=open("uasb.text","a")
file.write("\nwelcome")
file.close()

# %%
file=open("uasb.text",'r')
content=file.read()
print(content)
file.close()
# Out:
# welcomewelcomewelcome
# welcome

# %%
file=open("gkvk.text",'r')
content=file.readline()
print(content)
file.close()
# Out:
# good morning

# %%
file=open("gkvk.text",'r')
content=file.readlines()
print(content)
file.close()
# Out:
# ['good morning\n', 'how are you guys..\n', 'how are you guys..']

# %%
with open("span.text","r") as file:
  print(file.read())
# Out:
# today is colourful day/n enjoy it

# %%
with open("span.text","w") as file:
  file.write("today is colourful day")

# %%
with open("span.text","a") as file:
  file.write("/n enjoy it")

# %%
try:
    file=open("sonu.text","r")
    content=file.read()
    print(content)
    file.close()
except:
  print("file not found")
# Out:
# file not found

# %%
try:
  a=10
  b=20
  c=a+d
  print(c)
except:
  print("some issue")
# Out:
# some issue

# %%
def exp(a,b):
  c=a/b
  print(c)
a=10
b=40
exp(a,b)
# Out:
# 0.25

# %%
def exp(a,b):
  try:
    c=a/f
  except ZeroDivisionError:
    print("divided by zero")
  except NameError:
    print("variable not declared")
  except:
    print("some error occured")
  else:
    print("excuted without error")
    print("value of c",c)
  finally: print("end of program")
a=50
b=20
exp(a,b)
# Out:
# variable not declared
# end of program
